# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
df = pd.read_csv('pokemon.csv')

# %%
df = df.drop(columns=["Name", "#"])

# %%
Y_type1_encoded = LE.fit_transform(df["Type 1"]).astype(int)
Y_type1_encoded = pd.Series(Y_type1_encoded, index=df.index).rename('Type_1_Encoded')

# %%
Y_existence = df['Type 2'].notna().astype(int).rename('Has_Dual_Type')

# %%
df['Type 2_Fill'] = df['Type 2'].fillna('No_Type_2')

# %%
Y_type2_encoded = LE.fit_transform(df['Type 2_Fill']).astype(int)
Y_type2_encoded = pd.Series(Y_type2_encoded, index=df.index).rename('Type_2_Encoded')

# %%
Y = pd.concat([Y_type1_encoded, Y_existence, Y_type2_encoded], axis=1)
X = df.drop(columns=['Type 1', 'Type 2', 'Type 2_Fill'])

# %%
Rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)
Rf.fit(X, Y)
joblib.dump(Rf, 'pokemon_classifier.pkl')
# Out:
# ['pokemon_classifier.pkl']
